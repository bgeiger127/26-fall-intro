# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# # Review

# %%
cones = Table.read_table('cones.csv')
cones

# %% [markdown]
# ### Practice
#
# Find the percentage of rows that have 'pink' in the Color row.
#
# - Use .where to find create a table containing all the 'pink' rows.
# - Use .num_rows to find the number of rows in a table.

# %% [markdown]
# ## Numbers ##
#
# Textbook section 4.1

# %%
3 * 30 # int

# %%
10 / 3 # float

# %%
3 / 3 # float

# %%
10 ** 3 # 10 * 10 * 10

# %%
10 ** 0.5 # float

# %%
12345678 ** 890

# %%
75892745.215489247589274985712 - 75892745.21548925

# %%
10 / 5

# %%
int(10 / 5)

# %%
16 / 30

# %%
round(16 / 30), int(16 / 30)

# %%
float(3)

# %% [markdown]
# ## Strings ##
#
# Textbook section 4.2

# %%
'Flavor'

# %%
"Flavor"

# %%
Flavor

# %%
'straw' + 'berry'

# %%
5 + '5'

# %%
5 + int('5')

# %%
'yelp review: ' + str(10)

# %%
str(int('10'))

# %% [markdown]
# ## Arrays ##
#
# Textbook section 5.1

# %%
my_array = make_array(1, 2, 3)
my_array

# %%
type(my_array)

# %%
len(my_array)

# %%
my_array + 2

# %%
my_array

# %%
my_array_plus_two = my_array + 2
my_array_plus_two

# %%
my_array * 2

# %%
my_array ** 2

# %%
my_array_2 = make_array(-1, -2, -1)
my_array_2

# %%
my_array_2 + my_array

# %%
my_array_3 = make_array(1,2,3,4)
my_array_3

# %%
my_array + my_array_3

# %%
names_array = make_array('Andrew', 'Conan', 'Jonathan')
names_array

# %%
names_array.item(0)

# %%
names_array.item(1)

# %%
names_array.item(3)
